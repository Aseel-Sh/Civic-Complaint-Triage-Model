# %% [markdown]
# # 01 - Load and Clean Data
#
# This notebook downloads the raw complaint data and produces a cleaned dataset with a delayed target.

# %% [markdown]
# ## Set up paths
# We add the project `src` folder to the Python path so we can import the scripts as modules.

# %%
from pathlib import Path
import sys

project_root = Path('..').resolve()
sys.path.append(str(project_root / 'src'))
project_root

# %% [markdown]
# ## Download raw data
# This step pulls the public CSV and saves it to `data/raw/complaints.csv`.

# %%
from download_data import download_data

raw_df = download_data()
raw_df.head()

# %% [markdown]
# ## Clean data and create target
# We parse dates, compute `days_to_resolution`, and define the `delayed` target.

# %%
from clean_data import clean_data

clean_df = clean_data()
clean_df.head()
